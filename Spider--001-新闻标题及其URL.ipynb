# %%
'''
本文以'链节点'网站为例，实现新闻标题及其URL批量获取，并以字典的形式存入本地。
代码使用python的requests模块，并以json格式转存本地。
分成3步：1,发请求；2,解析数据；3,保存数据。

'''

import requests
from lxml import etree
import re
import json
import time

class BtcSpider(object):
    def __init__(self):
        self.base_url = 'https://www.chainnode.com/forum/61-'
        self.headers = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/73.0.3683.86 Chrome/73.0.3683.86 Safari/537.36'}
        self.news_name = []
        self.news_url = []

    # 1,发请求：
    def get_response(self, url):
        response = requests.get(url, headers = self.headers)
        data = response.content.decode()
        return data

    # 2,解析数据：
    def parse_data(self, data):
        # 1,转类型; 使用xpath解析网页
        x_data = etree.HTML(data)

        # 2,xpath路径解析：        
        result2 = x_data.xpath('//a[@class ="link-dark-major font-bold bbt-block"]/text()')  # 返回新闻标题
        result3 = x_data.xpath('//a[@class ="link-dark-major font-bold bbt-block"]/@href')   # 返回新闻url

        for i in result2:                         # 使用re规范化新闻标题
            result = re.sub(r'\s+', '', i)
            self.news_name.append(result)

        url_head = 'https://www.chainnode.com'
        for i in range(len(result3)):             # 合成新闻完整的url
            url_element = url_head + result3[i]
            self.news_url.append(url_element)
        # print(news_url)

        news_name_url = dict(zip(self.news_name, self.news_url))  # 将新闻标题与新闻url一一对应起来,组成一个字典
        #print(news_name_url)

        return news_name_url

    # 3,保存数据：
    def save_data(self, data):

        news_data = json.dumps(data)
        with open('../OutPut/dict_of_news_name_url.json', 'w') as f:  # 将字典以json格式保存到本地
            f.write(news_data)

    # 4,爬虫走起：
    def run(self):

        for i in range(1, 100):  # 爬取前100页新闻标题与其对应的url
            # 1),拼接完整的url:
            url = self.base_url + str(i)
            print(url)
            # 2),发请求：
            data = self.get_response(url)
            # 3),做解析：
            data_news = self.parse_data(data)

        # 4),保存数据：
        self.save_data(data_news)


start = time.time()
BtcSpider().run()
# 读取保存的json文件,检验是否成功：
with open('../OutPut/dict_of_news_name_url.json', 'r') as f:
    data_dict = json.load(f)
print(data_dict)  # 成功打印
print(len(data_dict))
end = time.time()
print('cost time: ', end-start, 's')
# Out:
# https://www.chainnode.com/forum/61-1
# https://www.chainnode.com/forum/61-2
# https://www.chainnode.com/forum/61-3
# https://www.chainnode.com/forum/61-4
# https://www.chainnode.com/forum/61-5
# https://www.chainnode.com/forum/61-6
# https://www.chainnode.com/forum/61-7
# https://www.chainnode.com/forum/61-8
# https://www.chainnode.com/forum/61-9
# https://www.chainnode.com/forum/61-10
# https://www.chainnode.com/forum/61-11
# https://www.chainnode.com/forum/61-12
# https://www.chainnode.com/forum/61-13
# https://www.chainnode.com/forum/61-14
# https://www.chainnode.com/forum/61-15
# https://www.chainnode.com/forum/61-16
# https://www.chainnode.com/forum/61-17
# https://www.chainnode.com/forum/61-18
# https://www.chainnode.com/forum/61-19
# https://www.chainnode.com/forum/61-20
# https://www.chainnode.com/forum/61-21
# https://www.chainnode.com/forum/61-22
# https://www.chainnode.com/forum/61-23
# https://www.chainnode.com/forum/61-24
# https://www.chainnode.com/forum/61-25
# https://www.chainnode.com/forum/61-26
# https://www.chainnode.com/forum/61-27
# https://www.chainnode.com/forum/61-28
# https://www.chainnode.com/forum/61-29
# https://www.chainnode.com/forum/61-30
# https://www.chainnode.com/forum/61-31
# https://www.chainnode.com/forum/61-32
# https://www.chainnode.com/forum/61-33
# https://www.chainnode.com/forum/61-34
# https://www.chainnode.com/forum/61-35
# https://www.chainnode.com/forum/61-36
# https://www.chainnode.com/forum/61-37
# https://www.chainnode.com/forum/61-38
# https://www.chainnode.com/forum/61-39
# https://www.chainnode.com/forum/61-40
# https://www.chainnode.com/forum/61-41
# https://www.chainnode.com/forum/61-42
# https://www.chainnode.com/forum/61-43
# https://www.chainnode.com/forum/61-44
# https://www.chainnode.com/forum/61-45
# https://www.chainnode.com/forum/61-46
# https://www.chainnode.com/forum/61-47
# https://www.chainnode.com/forum/61-48
# https://www.chainnode.com/forum/61-49
# https://www.chainnode.com/forum/61-50
# https://www.chainnode.com/forum/61-51
# https://www.chainnode.com/forum/61-52
# https://www.chainnode.com/forum/61-53
# https://www.chainnode.com/forum/61-54
# https://www.chainnode.com/forum/61-55
# https://www.chainnode.com/forum/61-56
# https://www.chainnode.com/forum/61-57
# https://www.chainnode.com/forum/61-58
# https://www.chainnode.com/forum/61-59
# https://www.chainnode.com/forum/61-60
# https://www.chainnode.com/forum/61-61
# https://www.chainnode.com/forum/61-62
# https://www.chainnode.com/forum/61-63
# https://www.chainnode.com/forum/61-64
# https://www.chainnode.com/forum/61-65
# https://www.chainnode.com/forum/61-66
# https://www.chainnode.com/forum/61-67
# https://www.chainnode.com/forum/61-68
# https://www.chainnode.com/forum/61-69
# https://www.chainnode.com/forum/61-70
# https://www.chainnode.com/forum/61-71
# https://www.chainnode.com/forum/61-72
# https://www.chainnode.com/forum/61-73
# https://www.chainnode.com/forum/61-74
# https://www.chainnode.com/forum/61-75
# https://www.chainnode.com/forum/61-76
# https://www.chainnode.com/forum/61-77
# https://www.chainnode.com/forum/61-78
# https://www.chainnode.com/forum/61-79
# https://www.chainnode.com/forum/61-80
# https://www.chainnode.com/forum/61-81
# https://www.chainnode.com/forum/61-82
# https://www.chainnode.com/forum/61-83
# https://www.chainnode.com/forum/61-84
# https://www.chainnode.com/forum/61-85
# https://www.chainnode.com/forum/61-86
# https://www.chainnode.com/forum/61-87
# https://www.chainnode.com/forum/61-88
# https://www.chainnode.com/forum/61-89
# https://www.chainnode.com/forum/61-90
# https://www.chainnode.com/forum/61-91
# https://www.chainnode.com/forum/61-92
# https://www.chainnode.com/forum/61-93
# https://www.chainnode.com/forum/61-94
# https://www.chainnode.com/forum/61-95
# https://www.chainnode.com/forum/61-96
# https://www.chainnode.com/forum/61-97
# https://www.chainnode.com/forum/61-98
# https://www.chainnode.com/forum/61-99
# {'今天＄422入手bch，447没抛，现在429好方。。': 'https://www.chainnode.com/post/330455', '目前行情看': 'https://www.chainnode.com/post/329038', '太子最近这俩波行情都蔫了': 'https://www.chainnode.com/post/330550', '比原价格表': 'https://www.chainnode.com/post/330537', '是时候出来喊句口号了！': 'https://www.chainnode.com/post/330548', 'abt从全仓到放弃': 'https://www.chainnode.com/post/330384', '形势一片大好': 'https://www.chainnode.com/post/330557', '链上闪电才是真正的闪电网络比特币10分钟莱特币2.5分钟无限币30秒': 'https://www.chainnode.com/post/316983', '狂人从3000开空开到了8000': 'https://www.chainnode.com/post/330540', '人生驴秃发表了一批怂人': 'https://www.chainnode.com/post/325550', '现在到底是熊市反弹还是牛初': 'https://www.chainnode.com/post/330502', 'bsv六月干掉bch，九月干掉btc': 'https://www.chainnode.com/post/330062', '你们以为大饼以太柚子涨了，事情就算完了？': 'https://www.chainnode.com/post/330402', 'BTM明天1.2以上': 'https://www.chainnode.com/post/326106', '别忘了你们来这是干嘛来了': 'https://www.chainnode.com/post/330553', '未来买大平台币还是主流币？': 'https://www.chainnode.com/post/329772', '来看看当年淘宝卖的btc。': 'https://www.chainnode.com/post/329874', 'btm涨点心吧': 'https://www.chainnode.com/post/330552', '美元增值+': 'https://www.chainnode.com/post/330551', '我就不明白了那些不看好比原的': 'https://www.chainnode.com/post/330544', '这波行情有点妖': 'https://www.chainnode.com/post/330468', '踏空的兄弟们不要悲伤': 'https://www.chainnode.com/post/330549', '好吧，我提示你们研究，赚钱的道理': 'https://www.chainnode.com/post/329946', '老子又神了一话，我警告大家bsv即将因为恐慌抛售而暴跌，一个小时后出现了': 'https://www.chainnode.com/post/329750', 'Core的闪电网络有人用吗？': 'https://www.chainnode.com/post/327496', 'BTC3000已经是铁底，很有可能历史大底': 'https://www.chainnode.com/post/291249', '预测BSV多伦多会议价格将达到1000块一枚': 'https://www.chainnode.com/post/330100', '币圈大魔王，每日行情分析！': 'https://www.chainnode.com/post/315887', '黑钻帝国年纪本卷一': 'https://www.chainnode.com/post/330546', '闪电网络与莱特币的竞争': 'https://www.chainnode.com/post/328340', '人生旅途是一个可笑无知的人。': 'https://www.chainnode.com/post/330506', '上七刀吧上了我就出了': 'https://www.chainnode.com/post/329297', '2019年FINWISE纷智峰会即将拉开序幕，BHD受邀出席': 'https://www.chainnode.com/post/330545', 'btc挖矿的风险': 'https://www.chainnode.com/post/330543', '大家都注意了，晚上睡觉时大家都有睡后收入的': 'https://www.chainnode.com/post/330535', 'nnd，老子一卖，不买就呼呼长，一买你就瞎跌': 'https://www.chainnode.com/post/330541', '矿圈曝光-无良矿场老板侵吞散户矿机押金': 'https://www.chainnode.com/post/329421', '有谁记得当年做梦万八，被笑疯子，如今我做梦560万': 'https://www.chainnode.com/post/330533', 'Eos六月份消息是啥？': 'https://www.chainnode.com/post/329299', '比特币大涨身边朋友个个@我': 'https://www.chainnode.com/post/330493', 'AisiEx上线MCQ/ETH': 'https://www.chainnode.com/post/330542', '听说长铗老家是湖南邵东的': 'https://www.chainnode.com/post/330400', '最近论坛很多朋友外场交易被冻结，区块链金融项目不就搞定这个问题了': 'https://www.chainnode.com/post/330539', 'EOS开始启动了': 'https://www.chainnode.com/post/330538', '其实柚子跌不了多少': 'https://www.chainnode.com/post/318599', 'Cmt的苦不堪言自述': 'https://www.chainnode.com/post/323421', 'HT，BCH，屯币至死！': 'https://www.chainnode.com/post/328473', '84RMB购入1500个ETH求大神指导': 'https://www.chainnode.com/post/37377', '教你玩转最安全的官网CORE钱包，包括离线交易': 'https://www.chainnode.com/post/191966', '想做一个混吃等死的社会垃圾': 'https://www.chainnode.com/post/330528', '场外交易银行卡防冻结': 'https://www.chainnode.com/post/330381', '团队在做事，能笑死': 'https://www.chainnode.com/post/330536', '你是不是被横下车了……': 'https://www.chainnode.com/post/330524', '真可笑，投资bch，bsv的人进来，玩弄一下你们的感情': 'https://www.chainnode.com/post/325518', '梅冻主区块链投资试验：一起实现千万盈利！': 'https://www.chainnode.com/post/130397', '今天又加了20000rmb的比特币，等明年减半后买房看能不能付个首付！': 'https://www.chainnode.com/post/330534', '给所有比特币、莱特币、狗狗币的矿工们致敬': 'https://www.chainnode.com/post/330423', '深圳有币圈的朋友吗？': 'https://www.chainnode.com/post/230466', '马上要9000了！话说，炒币这么久，你有一枚完整的比特币吗？': 'https://www.chainnode.com/post/330444', '牛市是牛市，只是btc的牛市': 'https://www.chainnode.com/post/330525', '一万到一千万实盘记录。': 'https://www.chainnode.com/post/327030', '冷静，大家高兴一下，但是马上又要冷静下来好好想想吧！比特币这轮牛市可以暴涨几倍': 'https://www.chainnode.com/post/330401', 'Achain周报丨2019.5.20-5.26': 'https://www.chainnode.com/post/330532', '今晚比特分析行情': 'https://www.chainnode.com/post/330531', '谁知道昨天BTC为啥又猛涨的原因啊？': 'https://www.chainnode.com/post/330419', '建仓了1000个zec': 'https://www.chainnode.com/p ...
# 3411
# cost time:  155.6453537940979 s
